# %%
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
# trace1 = go.Scatter(
#     y = np.random.randn(500),
#     mode = 'markers',
#     marker = dict(
#         size = 16,
#         color = np.random.randn(500),
#         colorscale = 'Viridis',
#         showscale = True
#     )
# )
# fig = go.Figure(trace1)
# fig.show()
plt.figure(dpi=150)
plt.scatter(x=np.random.randn(500),y=np.random.randn(500),c=np.random.randn(500))
plt.colorbar()
plt.show()
