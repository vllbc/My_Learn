# %% [markdown]
# # 分析数据

# %%
import plotly
import plotly.graph_objects as go
import numpy as np
# def sigmod(x):
#     return 1/(1+np.exp(-x))
# liss = np.arange(-10,10,0.1)
# y = [sigmod(x) for x in liss]
# scatter = go.Scatter(x = liss,y = y,mode="lines")
# fig = go.Figure(scatter)
# fig.show()

# %%
import pandas as pd
data = pd.read_csv("test_Y3wMUE5_7gLdaTN.csv") #下载的贷款数据集
data.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate           NaN
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# ...

# %%
print(data.index,"\n",data.columns)
# Out:
# RangeIndex(start=0, stop=367, step=1)
#  Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data[data['Self_Employed'] == 'Yes' ].head()
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5   LP001054   Male     Yes          0  Not Graduate           Yes
# 37  LP001210   Male     Yes          0      Graduate           Yes
# 38  LP001211   Male      No          0      Graduate           Yes
# 49  LP001270   Male     Yes         3+  Not Graduate           Yes
# 54  LP001312   Male     Yes          0  Not Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5              2165               3422       152.0             360.0
# 37             2267               2792        90.0             360.0
# 38             5833                  0       116.0             360.0
# 49             8000                250       187.0             360.0
# 54             5293                  0        92.0             360.0
#
#     Credit_History Property_Area
# 5              1.0         Urban
# 37             1.0         Urban
# 38             1.0         Urban
# ...

# %%
import torch

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
data = data.dropna(subset=['LoanAmount','Loan_Amount_Term',''],how='any')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ad88576b6e48> in <module>()
#       1
# ----> 2 data = data.dropna(subset=['LoanAmount','Loan_Amount_Term',''],how='any')
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    3487                 check = indices == -1
#    3488                 if check.any():
# -> 3489                     raise KeyError(list(np.compress(check, subset)))
#    3490                 agg_obj = self.take(indices, axis=agg_axis)
#    3491
#
# KeyError: ['']

# %%
data.isnull().sum()
data.sort_values(by=['LoanAmount','ApplicantIncome']).head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 232  LP002306    Male     Yes          0      Graduate            No
# 21   LP001124  Female      No         3+  Not Graduate            No
# 53   LP001298    Male     Yes          2      Graduate            No
# 334  LP002849    Male     Yes          0      Graduate            No
# 249  LP002376    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 232             1173               1594        28.0             180.0
# 21              2083                  0        28.0             180.0
# 53              4116               1000        30.0             180.0
# 334             1516               1951        35.0             360.0
# 249             2925                  0        40.0             180.0
#
#      Credit_History Property_Area
# 232             1.0         Rural
# 21              1.0         Urban
# ...
